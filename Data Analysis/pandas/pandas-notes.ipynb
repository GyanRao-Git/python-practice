# %% [markdown]
# ### NOTES
#
# ```
# # 📥 Data Input/Output
# pd.read_csv()
# pd.read_excel()
# pd.read_json()
# pd.read_sql()
# pd.read_html()
# pd.to_csv()
# pd.to_excel()
# pd.to_json()
#
# # 📊 DataFrame Creation
# pd.DataFrame()
# pd.Series()
# pd.date_range()
# pd.concat()
# pd.merge()
# pd.join()
#
# # 📈 Data Inspection
# df.head()
# df.tail()
# df.info()
# df.describe()
# df.shape
# df.columns
# df.dtypes
# df.index
# df.memory_usage()
#
# # 🧹 Data Cleaning
# df.isnull()
# df.notnull()
# df.dropna()
# df.fillna()
# df.replace()
# df.duplicated()
# df.drop_duplicates()
# df.astype()
#
# # 🧮 Aggregation and Grouping
# df.sum()
# df.mean()
# df.median()
# df.min()
# df.max()
# df.std()
# df.count()
# df.value_counts()
# df.groupby()
# df.agg()
# df.pivot_table()
#
# # 🎯 Filtering and Selection
# df['column']
# df[['col1', 'col2']]
# df.loc[]
# df.iloc[]
# df.at[]
# df.iat[]
# df.query()
#
# # 🧱 Data Manipulation
# df.sort_values()
# df.sort_index()
# df.rename()
# df.set_index()
# df.reset_index()
# df.drop()
# df.insert()
# df.assign()
# df.apply()
# df.map()
# df.applymap()
#
# # 🕒 Date and Time
# pd.to_datetime()
# df['date'].dt.year
# df['date'].dt.month
# df['date'].dt.day
# df['date'].dt.weekday
# df['date'].dt.strftime()
#
# # 🔗 Combining DataFrames
# pd.concat()
# pd.merge()
# df.append()  # (deprecated in future versions, use concat instead)
#
# # 📌 Miscellaneous
# df.copy()
# df.to_numpy()
# df.nunique()
# df.sample()
# df.clip()
# df.corr()
#
# ```

# %%
import pandas as pd
